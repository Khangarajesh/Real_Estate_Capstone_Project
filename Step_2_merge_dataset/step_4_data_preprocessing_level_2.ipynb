# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("/content/drive/MyDrive/campus x /Capstone Project /gurgaon_properties.csv")

# %%
df.sample(5)
# Out:
#                                       property_name                society  \
# 3319                            3 BHK Flat in Sohna  signature global park
# 2502        6 Bedroom House for sale in DLF Phase 1         dlf city plots
# 1377                            2 BHK Flat in Sohna      gls arawali homes
# 2051                2 BHK Flat in Sector 79 Gurgaon     supertech araville
# 1349  6 Bedroom House for sale in Sector 55 Gurgaon                    NaN
#
#       price  price_per_sqft        area property_type  \
# 3319   0.90          8036.0  1120.00000          flat
# 2502  26.00         57206.0  4544.97780         house
# 1377   0.26          4513.0   576.00000          flat
# 2051   0.71          6061.0  1171.00000          flat
# 1349   5.60         20741.0  2699.96625         house
#
#                                            areaWithType  bedRoom  bathroom  \
# 3319                 Built Up area: 1120 (104.05 sq.m.)      3.0       2.0
# 2502                        Plot area 505(422.24 sq.m.)      6.0       7.0
# 1377                     Carpet area: 576 (53.51 sq.m.)      2.0       2.0
# 2051  Super Built up area 1295(120.31 sq.m.)Carpet a...      2.0       2.0
# 1349                        Plot area 300(250.84 sq.m.)      6.0       4.0
#
#      balcony                             additionalRoom  \
# 3319      0                               not available
# 2502     3+   Pooja Room,Study Room,Servant Room,Others
# 1377      2                               not available
# 2051     3+                                      others
# 1349      3                                Servant Room
#
#                                           address  floorNum      facing  \
# 3319     Sohna Sector 36, Sohna, Gurgaon, Haryana       2.0         NaN
# 2502          0000, DLF Phase 1, Gurgaon, Haryana       2.0  North-East
# 1377                      Sohna, Gurgaon, Haryana       4.0         NaN
# 2051  E 1706, Sector 79 Gurgaon, Gurgaon, Haryana      17.0       North
# 1349          Sector 55 Gurgaon, Gurgaon, Haryana       3.0        East
#
#             agePossession                                    nearbyLocations  \
# 3319  2024-03-01 00:00:00  ['Sector 55-56 metro', 'Global city centre', '...
# 2502      0 to 1 Year Old  ['Phase 2 Metro Station', 'Grand Mall', 'Jacar...
# 1377      1 to 5 Year Old  ['Huda City Centre', 'Golf Course Road', 'Delh...
# 2051      0 to 1 Year Old  ['Petrol Pump Indian Oil', 'Petrol Pump', 'Rao...
# 1349         10+ Year Old  ['Sector metro station', 'Sector metro station...
#
#                                             description  \
# 3319  Best in class property available at sector 36 ...
# 2502  505 sq.Y 6 bhk luxury villa \nIn dlf phase 1\n...
# 1377  Residential apartment for sell.Located on 4th ...
# 2051  This is your chance to own a 2 bhk residential...
# 1349  Luxurious villa for sale\nLocation - Sector 55...
#
#                                          furnishDetails  \
# 3319                                                NaN
# 2502  ['12 Fan', '1 Exhaust Fan', '6 Geyser', '1 Sto...
# 1377                                                NaN
# 2051  ['2 Wardrobe', '2 Geyser', '1 Light', '2 AC', ...
# 1349  ['10 Fan', '4 Geyser', '12 Light', '4 AC', '1 ...
#
#                                                features  \
# 3319                                                NaN
# 2502  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1377  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 2051  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 1349  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                                  rating
# 3319  ['Green Area5 out of 5', 'Amenities5 out of 5'...
# 2502  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 1377  ['Green Area5 out of 5', 'Construction4 out of...
# 2051  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1349  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.insert(3, column = 'sector', value = df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip().str.lower())

# %%
df.head(2)
# Out:
#                      property_name                society  price     sector  \
# 0  3 BHK Flat in Sector 67 Gurgaon    ireo victory valley   2.99  sector 67
# 1              2 BHK Flat in Sohna  signature global park   0.58      sohna
#
#    price_per_sqft    area property_type  \
# 0         11832.0  2527.0          flat
# 1          7056.0   822.0          flat
#
#                                         areaWithType  bedRoom  bathroom  ...  \
# 0  Super Built up area 2527(234.77 sq.m.)Built Up...      3.0       3.0  ...
# 1  Built Up area: 822 (76.37 sq.m.)Carpet area: 6...      2.0       2.0  ...
#
#   additionalRoom                                   address floorNum  facing  \
# 0   servant room  702, Sector 67 Gurgaon, Gurgaon, Haryana      4.0    East
# 1  not available  Sohna Sector 36, Sohna, Gurgaon, Haryana      3.0     NaN
#
#      agePossession                                    nearbyLocations  \
# 0  1 to 5 Year Old  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 1        undefined  ['Sector 55-56 metro', 'Global city centre', '...
#
#                                          description  \
# 0  Note- We deal exclusively in the society ireo ...
# 1  Best in class property available at sector 36 ...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 St...
# 1                                                NaN
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Intercom Facility',...
# 1                                                NaN
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4 out of...
# 1  ['Green Area5 out of 5', 'Construction5 out of...
#
# [2 rows x 21 columns]

# %%
df['sector'].value_counts()
# Out:
# sohna                       164
# sector 102                  113
# sector 85                   110
# sector 92                   105
# sector 109                  103
#                            ...
# mahavir pura                  1
# heera nagar                   1
# anand garden, sector-105      1
# shivji park colony            1
# garauli kalan                 1
# Name: sector, Length: 305, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3].index

# %%
df = df[df['sector'].isin(a)]

# %%
df['sector'].value_counts()
# Out:
# sohna road           164
# sector 102           113
# sector 85            110
# sector 92            105
# sector 109           103
#                     ...
# bissar                 3
# sector 27              3
# a block sector 43      3
# sector 17b             3
# sector 17a             3
# Name: sector, Length: 134, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name                       society  price sector  \
# 1268  4 BHK Flat in New Gurgaon                        dlf 76   4.00    new
# 2661  2 BHK Flat in New Gurgaon                   green court   0.38    new
# 2834  2 BHK Flat in New Gurgaon  takshila heights sector 37 c   0.67    new
# 3061  4 BHK Flat in New Gurgaon                    sare homes   0.85    new
#
#       price_per_sqft    area property_type  \
# 1268         11428.0  3500.0          flat
# 2661          5507.0   690.0          flat
# 2834          5583.0  1200.0          flat
# 3061          4786.0  1776.0          flat
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 1268        Carpet area: 3500 (325.16 sq.m.)      4.0       4.0  ...
# 2661           Carpet area: 690 (64.1 sq.m.)      2.0       2.0  ...
# 2834  Super Built up area 1200(111.48 sq.m.)      2.0       2.0  ...
# 3061     Super Built up area 1776(165 sq.m.)      4.0       4.0  ...
#
#                additionalRoom                        address floorNum  facing  \
# 1268  study room,servant room  New Gurgaon, Gurgaon, Haryana      4.0     NaN
# 2661            not available  New Gurgaon, Gurgaon, Haryana      7.0     NaN
# 2834            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 3061            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
#
#             agePossession                                    nearbyLocations  \
# 1268  2027-06-01 00:00:00  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2661   Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 2834      1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3061     5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
#
#                                             description  \
# 1268  This lovely 4 bhk apartment/flat in new gurgao...
# 2661  We are the proud owners of this 2 bhk apartmen...
# 2834  Check out this 2 bhk apartment for sale in tak...
# 3061  Located in the popular residential address of ...
#
#                                          furnishDetails  \
# 1268  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2661                                                 []
# 2834                                                 []
# 3061                                                 []
#
#                                                features rating
# 1268  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 2661  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 2834  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 3061                                                NaN    NaN
#
# [4 rows x 21 columns]

# %%
df.loc[2834, 'sector'] = 'sector 37'
df.loc[3061,'sector'] = 'sector 92'
df.loc[2661,'sector'] = 'sector 90'
df.loc[1268,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name              society  price  \
# 401   3 Bedroom House for sale in New Palam Vihar                  NaN   1.00
# 464                 2 BHK Flat in New Palam Vihar  ompee k s residency   1.60
# 939                 2 BHK Flat in New Palam Vihar              my home   0.22
# 2010  2 Bedroom House for sale in New Palam Vihar              my home   0.34
# 2977  2 Bedroom House for sale in New Palam Vihar                  NaN    NaN
# 3810                2 BHK Flat in New Palam Vihar              my home   0.28
#
#             sector  price_per_sqft         area property_type  \
# 401   new sector 2          8796.0  1136.880400         house
# 464   new sector 2         26936.0   594.000000          flat
# 939   new sector 2          4400.0   500.000000          flat
# 2010  new sector 2         12592.0   270.012706         house
# 2977  new sector 2          8000.0          NaN         house
# 3810  new sector 2          3166.0   884.000000          flat
#
#                                            areaWithType  bedRoom  bathroom  \
# 401   Plot area 120(100.34 sq.m.)Built Up area: 120 ...      3.0       2.0
# 464                       Carpet area: 66 (55.18 sq.m.)      2.0       2.0
# 939                      Carpet area: 500 (46.45 sq.m.)      2.0       2.0
# 2010                         Plot area 270(25.08 sq.m.)      2.0       2.0
# 2977                                                NaN      NaN       NaN
# 3810                     Carpet area: 900 (83.61 sq.m.)      2.0       1.0
#
#       ... additionalRoom                                            address  \
# 401   ...     Pooja Room  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...
# 464   ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 939   ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 2010  ...  Not Available         Ez-19 A, New Palam Vihar, Gurgaon, Haryana
# 2977  ...  Not Available                                                NaN
# 3810  ...         others         F 150/b, New Palam Vihar, Gurgaon, Haryana
#
#      floorNum  facing     agePossession  \
# 401       1.0   North      10+ Year Old
# 464       1.0     NaN   1 to 5 Year Old
# 939       1.0     NaN   0 to 1 Year Old
# 2010      3.0    West  5 to 10 Year Old
# 2977      NaN     NaN               NaN
# 3810      2.0     NaN   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 401   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 464   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 939   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2010  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2977                                                NaN
# 3810  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 401   Ground and first floor, Ground floor: Ground f...
# 464   We are the proud owners of this 2 bhk apartmen...
# 939   Cctv surveillance are provided here. There is ...
# 2010  There are availability of various facilities l...
# 2977                                                NaN
# 3810  2 bhk room with wooden coverd ,1 drawing room,...
#
#                                          furnishDetails  \
# 401                                                 NaN
# 464                                                 NaN
# 939   ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 2010  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 2977                                                NaN
# 3810  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
#
#                                           features  \
# 401                                            NaN
# 464                                            NaN
# 939                                            NaN
# 2010  ['Water Storage', 'Park', 'Visitor Parking']
# 2977                                           NaN
# 3810                     ['Water Storage', 'Park']
#
#                                                  rating
# 401   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 464   ['Environment4 out of 5', 'Safety4 out of 5', ...
# 939   ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 2010  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2977                                                NaN
# 3810  ['Environment4 out of 5', 'Safety4 out of 5', ...
#
# [6 rows x 21 columns]

# %%
df[df['sector'] == 'new sector 2'].index
# Out:
# Int64Index([401, 464, 939, 2010, 2977, 3810], dtype='int64')

# %%
df.loc[[401, 464, 939, 2010, 2977, 3810], 'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3925, 21)

# %%
df.duplicated().sum()
# Out:
# 23

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (3902, 21)

# %%
df.head()
# Out:
#                                    property_name                society  \
# 0                3 BHK Flat in Sector 67 Gurgaon    ireo victory valley
# 1                            2 BHK Flat in Sohna  signature global park
# 2                2 BHK Flat in Sector 71 Gurgaon             chd avenue
# 3                3 BHK Flat in Sector 43 Gurgaon    ansal maple heights
# 4  5 Bedroom House for sale in Sector 15 Gurgaon   sector 15 part 2 rwa
#
#    price      sector  price_per_sqft      area property_type  \
# 0   2.99   sector 67         11832.0  2527.000          flat
# 1   0.58  sohna road          7056.0   822.000          flat
# 2   0.95   sector 71          7917.0  1200.000          flat
# 3   1.50   sector 43         12658.0  1185.000          flat
# 4  10.00   sector 15         22222.0  4500.045         house
#
#                                         areaWithType  bedRoom  bathroom  ...  \
# 0  Super Built up area 2527(234.77 sq.m.)Built Up...      3.0       3.0  ...
# 1  Built Up area: 822 (76.37 sq.m.)Carpet area: 6...      2.0       2.0  ...
# 2                 Built Up area: 1200 (111.48 sq.m.)      2.0       2.0  ...
# 3  Super Built up area 1400(130.06 sq.m.)Built Up...      3.0       3.0  ...
# 4                        Plot area 502(419.74 sq.m.)      5.0       5.0  ...
#
#   additionalRoom                                         address floorNum  \
# 0   servant room        702, Sector 67 Gurgaon, Gurgaon, Haryana      4.0
# 1  not available        Sohna Sector 36, Sohna, Gurgaon, Haryana      3.0
# 2  not available  Sector 71, Sector 71 Gurgaon, Gurgaon, Haryana      5.0
# 3     store room       7-03, Sector 43 Gurgaon, Gurgaon, Haryana      7.0
# 4  Not Available             Sector 15 Gurgaon, Gurgaon, Haryana      2.0
#
#        facing    agePossession  \
# 0        East  1 to 5 Year Old
# 1         NaN        undefined
# 2       South        undefined
# 3  North-East     10+ Year Old
# 4        East     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 1  ['Sector 55-56 metro', 'Global city centre', '...
# 2  ['Huda City Centre', 'Apna Mart', 'Rajiv Chowk...
# 3  ['Huda city centre metro station', 'Iffco chow...
# 4  ['Hanuman Mandir', 'State bank of india ATM', ...
#
#                                          description  \
# 0  Note- We deal exclusively in the society ireo ...
# 1  Best in class property available at sector 36 ...
# 2  Best in class property available at sector 71 ...
# 3  Ansal maple heights in sector 43, gurgaon is a...
# 4  Gated community and near market,school and hig...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 St...
# 1                                                NaN
# 2  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3  ['3 Wardrobe', '1 Water Purifier', '10 Fan', '...
# 4                                                 []
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Intercom Facility',...
# 1                                                NaN
# 2                                                NaN
# 3  ['Centrally Air Conditioned', 'Water purifier'...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4 out of...
# 1  ['Green Area5 out of 5', 'Construction5 out of...
# 2  ['Green Area5 out of 5', 'Construction3 out of...
# 3  ['Green Area4 out of 5', 'Construction4 out of...
# 4  ['Environment4.5 out of 5', 'Lifestyle4 out of...
#
# [5 rows x 21 columns]

# %% [markdown]
# #Drop unnecessary columns

# %%
df.drop(columns = ['property_name', 'address', 'description', 'rating'], inplace = True)

# %%
df.sample(5)
# Out:
#                    society  price      sector  price_per_sqft         area  \
# 1540          corona optus   1.25  sector 37c          8928.0  1400.000000
# 3836                   NaN  11.00   sector 28         33951.0  3239.963477
# 1503  sunischit apartments   1.75   sector 54          7954.0  2200.000000
# 1668        dlf the primus   2.20  sector 82a         10516.0  2092.000000
# 1827     unitech sunbreeze   0.75   sector 69          6849.0  1095.000000
#
#      property_type                                       areaWithType  \
# 1540          flat  Super Built up area 1735(161.19 sq.m.)Carpet a...
# 3836         house                        Plot area 360(301.01 sq.m.)
# 1503          flat  Super Built up area 2200(204.39 sq.m.)Built Up...
# 1668          flat             Super Built up area 2092(194.35 sq.m.)
# 1827          flat             Super Built up area 1095(101.73 sq.m.)
#
#       bedRoom  bathroom balcony                      additionalRoom  floorNum  \
# 1540      3.0       3.0      3                           study room       2.0
# 3836     13.0      13.0     3+   Pooja Room,Study Room,Servant Room       3.0
# 1503      3.0       3.0     3+                         servant room       6.0
# 1668      3.0       3.0     3+                         servant room      16.0
# 1827      2.0       2.0      2                        not available       4.0
#
#           facing     agePossession  \
# 1540  South-East   1 to 5 Year Old
# 3836        East   1 to 5 Year Old
# 1503  North-East  5 to 10 Year Old
# 1668  North-East   1 to 5 Year Old
# 1827         NaN           By 2024
#
#                                         nearbyLocations  \
# 1540  ['The Esplanade Mall', 'Gurugram Road', 'Delhi...
# 3836  ['Dlf phase 1 metro station', 'Huda city centr...
# 1503  ['Sector metro station', 'Sector metro station...
# 1668  ['Sapphire 83', 'NH 48', 'Cambridge Montessori...
# 1827  ['Sri Radhe Krishna Temple', 'Icici bank ATM',...
#
#                                          furnishDetails  \
# 1540                                                NaN
# 3836  ['1 Water Purifier', '16 Fan', '1 Exhaust Fan'...
# 1503  ['4 Fan', '1 Exhaust Fan', '3 Geyser', '24 Lig...
# 1668  ['1 Water Purifier', '6 Fan', '1 Fridge', '1 E...
# 1827                                                 []
#
#                                                features
# 1540  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 3836  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1503  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1668  ['Centrally Air Conditioned', 'Water purifier'...
# 1827                                                NaN

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv', index = False)
