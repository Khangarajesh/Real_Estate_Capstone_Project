# %%
import pandas as pd
import numpy as np
import  re

# %%
independent_house = pd.read_excel("/content/independent-house.xlsx")

# %%
independent_house['society'].value_counts()
# Out:
# Vipul Tatvam Villa                     27
# International City by SOBHA Phase 2    26
# Emaar MGF Marbella                     26
# International City by Sobha Phase 1    23
# Unitech Uniworld Resorts               14
#                                        ..
# Madan puri                              1
# My Home                                 1
# ROW HOUSE                               1
# HUDA Plot Sector 38                     1
# HUDA Housing Board Colony4.1 ★          1
# Name: society, Length: 188, dtype: int64

# %%
independent_house.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
independent_house.shape
# Out:
# (1095, 21)

# %%
independent_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1095 non-null   object
#  1   link             1095 non-null   object
#  2   society          471 non-null    object
#  3   price            968 non-null    object
#  4   rate             1054 non-null   object
#  5   area             1095 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
independent_house.isna().mean().sort_values(ascending = False)*100
# Out:
# society            56.986301
# additionalRoom     46.210046
# features           38.447489
# facing             38.447489
# furnishDetails     32.146119
# rating             17.168950
# nearbyLocations    16.621005
# noOfFloor          11.689498
# price              11.598174
# areaWithType        9.863014
# bedRoom             9.863014
# bathroom            9.863014
# balcony             9.863014
# agePossession       9.863014
# address             5.844749
# description         5.388128
# property_id         5.388128
# rate                3.744292
# link                0.000000
# area                0.000000
# property_name       0.000000
# dtype: float64

# %% [markdown]
# Removing unnecessary columns

# %%
independent_house.drop(columns = {'link', 'property_id'}, inplace = True)

# %%
independent_house.sample(2)
# Out:
#                                           property_name               society  \
# 1093  8 Bedroom House for sale in C Block Sushant Lo...                   NaN
# 321              5 Bedroom House for sale in Bhim Nagar  bhim nagar, sector 6
#
#        price              rate                   area  \
# 1093     NaN   ₹ 31,008/sq.ft.  (180 sq.m.) Plot Area
# 321   85 Lac  ₹ 126,865/sq.ft.    (6 sq.m.) Plot Area
#
#                   areaWithType     bedRoom     bathroom      balcony  \
# 1093                       NaN         NaN          NaN          NaN
# 321   Plot area 67(6.22 sq.m.)  5 Bedrooms  2 Bathrooms  2 Balconies
#
#      additionalRoom                                  address noOfFloor facing  \
# 1093            NaN                                      NaN       NaN    NaN
# 321      Pooja Room  H.N0- 159, Bhim Nagar, Gurgaon, Haryana  1 Floors    NaN
#
#      agePossession                                    nearbyLocations  \
# ...

# %% [markdown]
# #Dealing with price column

# %%
independent_house['price'].unique()
# Out:
# array(['5.25 Crore', '5.7 Crore', '2.1 Crore', '5 Crore', '3 Crore',
#        '4.5 Crore', '12 Crore', '20 Crore', '10.85 Crore', '1.95 Crore',
#        '4.45 Crore', '9 Crore', '15 Crore', '8.25 Crore', '2 Crore',
#        '10.75 Crore', '7.35 Crore', '3.4 Crore', '8.4 Crore', '8.5 Crore',
#        '7.6 Crore', '7 Crore', '4.75 Crore', '3.5 Crore', '10.56 Crore',
#        '5.46 Crore', '10 Crore', '3.3 Crore', '13 Crore', '7.2 Crore',
#        '6 Crore', '5.8 Crore', '55.11 Lac', '7.49 Crore', '13.5 Crore',
#        '11.95 Crore', '12.39 Crore', '6.25 Crore', nan, '5.4 Crore',
#        '5.75 Crore', '2.55 Crore', '5.6 Crore', '17 Crore', '7.99 Crore',
#        '3.75 Crore', '7.25 Crore', '3.55 Crore', '2.5 Crore', '6.5 Crore',
#        '9.5 Crore', '5.5 Crore', '5.65 Crore', '8.8 Crore', '3.25 Crore',
#        '10.45 Crore', '19.5 Crore', '7.5 Crore', '67 Lac', '3.2 Crore',
#        '11.5 Crore', '7.69 Crore', '1.55 Crore', '3.85 Crore',
# ...

# %%
independent_house[independent_house['price'] == 'Price on Request'].shape
# Out:
# (10, 19)

# %% [markdown]
# we can see there are only 10 rows containing price value as 'Price on Request'. since thi column is going to be a target column we can not keep this value in price column so we will drop this rows

# %%
independent_house = independent_house[independent_house['price'] != 'Price on Request']

# %% [markdown]
# Also this column is not consistent, it contains price both in crore and lakh, so we will make it consistent.

# %%
independent_house[independent_house['price'].str.split(' ').str.len() <= 2]
# Out:
#                                          property_name  \
# 0       5 Bedroom House for sale in Sector 70A Gurgaon
# 1     5 Bedroom House for sale in Sector 21A Faridabad
# 2     10 Bedroom House for sale in Sushant Lok Phase 1
# 3       21 Bedroom House for sale in Sector 54 Gurgaon
# 4     12 Bedroom House for sale in Sushant Lok Phase 1
# ...                                                ...
# 1086     4 Bedroom House for sale in Sector 26 Gurgaon
# 1087           3 Bedroom House for sale in DLF Phase 2
# 1088     3 Bedroom House for sale in Sector 26 Gurgaon
# 1089     3 Bedroom House for sale in Sector 26 Gurgaon
# 1090                3 Bedroom House for sale in Bissar
#
#                                        society       price              rate  \
# 0                             Bptp Visionnaire  5.25 Crore   ₹ 20,115/sq.ft.
# 1                                          NaN   5.7 Crore  ₹ 105,751/sq.ft.
# ...

# %%
def price_in_crore_KHANGAR(x):
  if type(x) == float:
    return x
  elif x[1] == 'Lac':
    return round(float(x[0])/100, 2 )
  else:
    return round(float(x[0]), 2)

# %%
independent_house['price'] = independent_house['price'].str.split(' ').apply(lambda x : price_in_crore_KHANGAR(x))

# %% [markdown]
# #Dealing with rate column

# %%
independent_house.sample(5)
# Out:
#                                          property_name  \
# 674            8 Bedroom House for sale in DLF Phase 3
# 328     4 Bedroom House for sale in Sector 109 Gurgaon
# 315             5 Bedroom House for sale in Jyoti Park
# 500  2 Bedroom House for sale in Mahalaxmi Garden, ...
# 464      4 Bedroom House for sale in Sector 69 Gurgaon
#
#                                  society  price             rate  \
# 674               DLF City Plots Phase 3   1.60  ₹ 29,629/sq.ft.
# 328  International City by SOBHA Phase 2    NaN  ₹ 14,045/sq.ft.
# 315                                  NaN   1.16  ₹ 11,693/sq.ft.
# 500                                  NaN   0.38   ₹ 8,444/sq.ft.
# 464                         Tulip Yellow   2.95  ₹ 16,389/sq.ft.
#
#                           area  \
# 674       (50 sq.m.) Plot Area
# 328  (363 sq.m.) Built-up Area
# 315       (92 sq.m.) Plot Area
# 500       (42 sq.m.) Plot Area
# 464      (167 sq.m.) Plot Area
#
# ...

# %%
independent_house = independent_house.rename(columns = {'rate' : 'price_per_sqft'})

# %%
independent_house['price_per_sqft'] = independent_house['price_per_sqft'].str.replace('₹', '').str.split('/').str.get(0).str.replace(',', '').astype(float)

# %%
independent_house.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# 0   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   5 Bedrooms   4 Bathrooms   2 Balconies
# 2  10 Bedrooms  10 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
#
# ...

# %% [markdown]
# #Dealing with bedRooom column

# %%
independent_house['bedRoom'].value_counts()
# Out:
# 4 Bedrooms     239
# 5 Bedrooms     195
# 3 Bedrooms     148
# 2 Bedrooms      88
# 6 Bedrooms      82
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      34
# 7 Bedrooms      31
# 12 Bedrooms     29
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: bedRoom, dtype: int64

# %%
independent_house['bedRoom'] = independent_house['bedRoom'].str.split(' ').str.get(0).astype(float)

# %% [markdown]
# #Dealing with bathroom column

# %%
independent_house['bathroom'].value_counts()
# Out:
# 4 Bathrooms     233
# 3 Bathrooms     166
# 5 Bathrooms     139
# 2 Bathrooms     114
# 6 Bathrooms      85
# 1 Bathroom       65
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      29
# 12 Bathrooms     23
# 10 Bathrooms     11
# 16 Bathrooms      8
# 18 Bathrooms      4
# 13 Bathrooms      4
# 11 Bathrooms      4
# 20 Bathrooms      3
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 36 Bathrooms      1
# 34 Bathrooms      1
# Name: bathroom, dtype: int64

# %%
independent_house['bathroom'] = independent_house['bathroom'].str.split(' ').str.get(0).astype(float)

# %% [markdown]
# #Dealing with balcony column

# %%
independent_house['balcony'].value_counts()
# Out:
# 3+ Balconies    373
# 2 Balconies     223
# 3 Balconies     161
# No Balcony      115
# 1 Balcony       105
# Name: balcony, dtype: int64

# %%
independent_house['balcony'] = independent_house['balcony'].str.replace('Balconies', '').str.replace('Balcony', '').str.replace('No', '0')

# %%
independent_house['balcony'].value_counts()
# Out:
# 3+     373
# 2      223
# 3      161
# 0      115
# 1      105
# Name: balcony, dtype: int64

# %%
independent_house.sample(5)
# Out:
#                                          property_name society  price  \
# 404           8 Bedroom House for sale in Laxman Vihar     NaN   1.10
# 137       3 Bedroom House for sale in Sector 7 Gurgaon     NaN   3.10
# 280  4 Bedroom House for sale in URBAN ESTATE, SECT...     NaN   3.75
# 292            6 Bedroom House for sale in Farukhnagar     NaN   2.30
# 618     10 Bedroom House for sale in Sector 11 Gurgaon     NaN   3.50
#
#      price_per_sqft                       area  \
# 404          6111.0      (167 sq.m.) Plot Area
# 137         13778.0      (209 sq.m.) Plot Area
# 280         20425.0      (171 sq.m.) Plot Area
# 292         25386.0       (84 sq.m.) Plot Area
# 618         15555.0  (209 sq.m.) Built-up Area
#
#                            areaWithType  bedRoom  bathroom balcony  \
# 404         Plot area 200(167.23 sq.m.)      8.0       4.0     3+
# 137         Plot area 250(209.03 sq.m.)      3.0       3.0      2
# ...

# %%
independent_house['additionalRoom'].value_counts()
# Out:
# Servant Room                                     82
# Pooja Room,Study Room,Servant Room,Store Room    63
# Others                                           59
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               34
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room                                       19
# Study Room,Servant Room                          19
# Servant Room,Store Room                          15
# Pooja Room,Study Room                            11
# Pooja Room,Store Room                            11
# Pooja Room,Others                                11
# Pooja Room,Store Room,Study Room,Servant Room     9
# Servant Room,Pooja Room                           8
# Servant Room,Others                               8
# Pooja Room,Servant Room,Store Room                7
# ...

# %%
independent_house['additionalRoom'].isna().sum()
# Out:
# 496

# %%
independent_house['additionalRoom'].fillna('Not Available',inplace = True)

# %% [markdown]
# #Dealing with noOfFloor

# %%
independent_house['noOfFloor'].value_counts()
# Out:
# 3 Floors     309
# 2 Floors     294
# 1 Floors     181
# 4 Floors     137
# 5 Floors       9
# 0 Floors       6
# 14 Floors      3
# 6 Floors       3
# 11 Floors      2
# 12 Floors      2
# 10 Floors      2
# 16 Floors      1
# 51 Floors      1
# 41 Floors      1
# 27 Floors      1
# 20 Floors      1
# 13 Floors      1
# 21 Floors      1
# 02 Floors      1
# 33 Floors      1
# Name: noOfFloor, dtype: int64

# %%
independent_house['noOfFloor'] = independent_house['noOfFloor'].str.split(' ').str.get(0).astype(float)

# %%
independent_house.rename(columns = {'noOfFloor' : 'floorNum'}, inplace = True)

# %% [markdown]
# #DDealing with facing column

# %%
independent_house.sample(3)
# Out:
#                                        property_name           society  price  \
# 968         10 Bedroom House for sale in DLF Phase 3               NaN   4.50
# 1066  12 Bedroom House for sale in Sector 26 Gurgaon  DLF City Phase 1   9.25
# 570   9 Bedroom House for sale in Gurgaon, Delhi NCR               NaN   1.50
#
#       price_per_sqft                    area  \
# 968          33333.0   (136 sq.m.) Plot Area
# 1066         47803.0   (180 sq.m.) Plot Area
# 570          16667.0  (84 sq.m.) Carpet Area
#
#                                            areaWithType  bedRoom  bathroom  \
# 968   Plot area 163(136.29 sq.m.)Built Up area: 160 ...     10.0       8.0
# 1066  Plot area 1935(179.77 sq.m.)Built Up area: 700...     12.0      12.0
# 570                      Carpet area: 900 (83.61 sq.m.)      9.0       3.0
#
#      balcony           additionalRoom  \
# 968      3+   Store Room,Servant Room
# 1066     3+   Servant Room,Pooja Room
# 570      3+             Not Available
#
# ...

# %%
independent_house['facing'].value_counts()
# Out:
# East          181
# North-East    159
# North         113
# West           75
# North-West     44
# South-East     40
# South          36
# South-West     25
# Name: facing, dtype: int64

# %%
independent_house['facing'].isna().sum()
# Out:
# 412

# %%
independent_house['facing'].fillna('NA', inplace = True)

# %%
independent_house['facing'].value_counts()
# Out:
# NA            412
# East          181
# North-East    159
# North         113
# West           75
# North-West     44
# South-East     40
# South          36
# South-West     25
# Name: facing, dtype: int64

# %% [markdown]
# #Add area column

# %%
independent_house.shape
# Out:
# (1085, 19)

# %%
independent_house['area'] = independent_house['price']*10000000/independent_house['price_per_sqft']

# %%
independent_house.insert(5, column = 'property_type', value = 'house')

# %%
independent_house.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN   2.10
#
#    price_per_sqft         area property_type                 areaWithType  \
# 0         20115.0  2609.992543         house  Plot area 290(242.48 sq.m.)
# 1        105751.0   539.001995         house   Plot area 539(50.07 sq.m.)
# 2         38251.0   549.005255         house       Plot area 61(51 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# 0      5.0       4.0     3+                         Servant Room
# 1      5.0       4.0      2   Store Room,Pooja Room,Servant Room
# 2     10.0      10.0     3+                         Servant Room
#
#                                      address  floorNum      facing  \
# ...

# %%
independent_house['society'].value_counts()
# Out:
# Vipul Tatvam Villa                     27
# International City by SOBHA Phase 2    26
# Emaar MGF Marbella                     26
# International City by Sobha Phase 1    23
# Unitech Uniworld Resorts               14
#                                        ..
# Madan puri                              1
# My Home                                 1
# ROW HOUSE                               1
# HUDA Plot Sector 38                     1
# HUDA Housing Board Colony4.1 ★          1
# Name: society, Length: 188, dtype: int64

# %%
pattern = r'(\d+\.\d+\ ★)'
independent_house['society'] = independent_house['society'].apply(lambda x : re.sub(pattern, '', str(x))).str.strip().str.lower()

# %%
independent_house.to_csv('/content/independent_house_cleaned.csv', index = True)

# %%
independent_house['society'].shape
# Out:
# (1085,)
